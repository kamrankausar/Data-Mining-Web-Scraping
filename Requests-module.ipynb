# %%
#Install the requests module
pip install requests
# Out:
#   File "<ipython-input-1-4e53d39f0be0>", line 2
#     pip install requests
#               ^
# SyntaxError: invalid syntax

# %%
#To the the version of requests module install using pip
pip show requests | grep Version

# %%
#Importing Module
import requests

# %%
#Getting a Web Page
r = requests.get('https://api.github.com/events')

# %%
type(r)
# Out:
# requests.models.Response

# %%
#Make an HTTP POST requests
r = requests.post("http://httpbin.org/post",data = {'key' : 'value'})

# %%
type(r)
# Out:
# requests.models.Response

# %%
r = requests.head('http://httpbin.org/get')

# %%
print(r.url)
# Out:
# http://httpbin.org/get

# %%
print(r.content)
# Out:
# b''

# %%
r = requests.get('https://api.github.com/events')

# %%
r.text
# Out:
# '[{"id":"5614521687","type":"PushEvent","actor":{"id":66254,"login":"camdagr8","display_login":"camdagr8","gravatar_id":"","url":"https://api.github.com/users/camdagr8","avatar_url":"https://avatars.githubusercontent.com/u/66254?"},"repo":{"id":84096037,"name":"reykjavikingur/breakfast-butter","url":"https://api.github.com/repos/reykjavikingur/breakfast-butter"},"payload":{"push_id":1655329043,"size":1,"distinct_size":0,"ref":"refs/heads/master","head":"f97e13d50f364eb729cdf1b28771106c5989f008","before":"bb62dce423e4bee659a319ac40d8767d4bd69adb","commits":[{"sha":"f97e13d50f364eb729cdf1b28771106c5989f008","author":{"email":"ctullos@resourceammirati.com","name":"Cameron Tullos"},"message":"Updated version number","distinct":false,"url":"https://api.github.com/repos/reykjavikingur/breakfast-butter/commits/f97e13d50f364eb729cdf1b28771106c5989f008"}]},"public":true,"created_at":"2017-04-03T12:32:28Z"},{"id":"5614521686","type":"PushEvent","actor":{"id":2488861,"login":"walterrenner","dis
# ...

# %%
r = requests.post('http://httpbin.org/post', data = {'key':'value'})

# %%
r.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key": "value"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Connection": "close", \n    "Content-Length": "9", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.12.4"\n  }, \n  "json": null, \n  "origin": "196.207.66.18", \n  "url": "http://httpbin.org/post"\n}\n'

# %%
r = requests.delete('http://httpbin.org/delete')

# %%
r.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Connection": "close", \n    "Content-Length": "0", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.12.4"\n  }, \n  "json": null, \n  "origin": "196.207.66.18", \n  "url": "http://httpbin.org/delete"\n}\n'

# %%
r = requests.put('http://httpbin.org/put', data = {'key':'value'})

# %%
r.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "key": "value"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Connection": "close", \n    "Content-Length": "9", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.12.4"\n  }, \n  "json": null, \n  "origin": "196.207.66.18", \n  "url": "http://httpbin.org/put"\n}\n'

# %%
r = requests.put('http://httpbin.org/put',data = {'requests':'2.12.4'})

# %%
r.text
# Out:
# '{\n  "args": {}, \n  "data": "", \n  "files": {}, \n  "form": {\n    "requests": "2.12.4"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Connection": "close", \n    "Content-Length": "15", \n    "Content-Type": "application/x-www-form-urlencoded", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.12.4"\n  }, \n  "json": null, \n  "origin": "196.207.66.18", \n  "url": "http://httpbin.org/put"\n}\n'

# %%
#Passing parameters in URLs
#Requests allows arguments as a dictionary of string using parameter "params" keyword
payload = {'requests': '2.12.04', 'python': '3'}

# %%
#Here params is use
r = requests.get('http://httpbin.org/get', params=payload)

# %%
#To check url
r.url
# Out:
# 'http://httpbin.org/get?requests=2.12.04&python=3'

# %%
#To display the content
r.text
# Out:
# '{\n  "args": {\n    "python": "3", \n    "requests": "2.12.04"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate", \n    "Connection": "close", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.12.4"\n  }, \n  "origin": "196.207.66.18", \n  "url": "http://httpbin.org/get?requests=2.12.04&python=3"\n}\n'

# %%
#Response Content 
#To check the Encoding
r = requests.get('https://api.github.com/events')
r.encoding
# Out:
# 'utf-8'

# %%
#To change the encoding for own use
r.encoding = 'ISO-8859-1'

# %%
#Now its Change
r.encoding
# Out:
# 'ISO-8859-1'

# %%
r = requests.get('http://httpbin.org')

# %%
r.encoding
# Out:
# 'utf-8'

# %%
#HTTP and XML have the ability to specify their encoding in their body.
#In situations like this, you should use 'r.content' to find the encoding, and then set 'r.encoding'.
#This will let you use 'r.text' with the correct encoding.

# %%
#Binary Response Content
#'gzip' and 'deflate' automatically decode content from requests
#To create an image from binary data returned by request
r = requests.get('https://api.github.com/events')

# %%
from PIL import Image
from io import BytesIO

# %%
i = Image.open(BytesIO(r.content))

# %%
#JSON Response Content
#There is built in JSON decoder
import requests
r = requests.get("https://api.github.com/events")

# %%
r.json()
# Out:
# [{'actor': {'avatar_url': 'https://avatars.githubusercontent.com/u/1913901?',
#    'display_login': 'GerardPaligot',
#    'gravatar_id': '',
#    'id': 1913901,
#    'login': 'GerardPaligot',
#    'url': 'https://api.github.com/users/GerardPaligot'},
#   'created_at': '2017-04-03T14:05:01Z',
#   'id': '5615167188',
#   'org': {'avatar_url': 'https://avatars.githubusercontent.com/u/7406239?',
#    'gravatar_id': '',
#    'id': 7406239,
#    'login': 'zestedesavoir',
#    'url': 'https://api.github.com/orgs/zestedesavoir'},
#   'payload': {'action': 'created',
#    'comment': {'body': 'Trop bien ! Merci @AmarOk1412 !!',
#     'created_at': '2017-04-03T14:05:01Z',
#     'html_url': 'https://github.com/zestedesavoir/zds-site/issues/736#issuecomment-291153347',
#     'id': 291153347,
#     'issue_url': 'https://api.github.com/repos/zestedesavoir/zds-site/issues/736',
#     'updated_at': '2017-04-03T14:05:01Z',
# ...

# %%
#Raw Response Content
#In the rare case that you'd like to get the raw socket response from the server, you can access r.raw. 
#If you want to do this, make sure you set stream=True in your initial request. 
#Once you do, you can do this:

# %%
r = requests.get('https://api.github.com/events', stream=True)

# %%
r.raw

# %%
r.raw.read(100)
# Out:
# b'*\xee\xe2\xb9\xbbU\xd6zp\xf9|\xe02\x12\x04\x06.\x16\xb6\xecY2a\x93\x86\xeey\xb2\xe3Z\x86\x82\xc9\xb1m\xdf\xc1W\xcc5\xf73\x9a\x8f{<\xf9d\xe4\xc4X\x8d\x88\xf2JJ\xf4\x8c\xd8I\xb1\xcb=\xd8z\xa8\x85\xd5\xd2^2\xeepv\xf8\n\xe1\xf5\xea\x84\x97R\x81-\xbd\x04\xd0\x18\x97\xa5\xa2\x00\xefqM\xaa\x96O\xad\x8f'

# %%
r = requests.get('https://api.github.com/events')

# %%
#Custom Headers
#Want to add HTTP headers to a request,Simply pass in a dict to the headers parameter
url = 'https://api.github.com/some/endpoint'
headers = {'user-agent':'my-app/0.0.1'}
r = requests.get(url,headers = headers)

# %%
r.text
# Out:
# '{"message":"Not Found","documentation_url":"https://developer.github.com/v3"}'

# %%
print(r.text)
# Out:
# {"message":"Not Found","documentation_url":"https://developer.github.com/v3"}

# %%
#Response Status Codes
#We can check the response status code:
r = requests.get("http://httpbin.org/get")
r.status_code
# Out:
# 200

# %%
#Requests also comes with a built-in status code lookup object for easy reference:
r.status_code == requests.codes.ok
# Out:
# True

# %%
#If we made a bad request (a 4XX client error or 5XX server error response)
bad_r = requests.get('http://httpbin.org/status/411')

# %%
bad_r.status_code
# Out:
# 411

# %%
#since our status_code for r was 200, when we call raise_for_status() we get:
r.raise_for_status()
#Output is nothing shows All is well
